# %%
import risk_controller

# %%
game_board = risk_controller.board(["Charlie", "Oana"])

# %%
print(game_board.current_player.name)
game_board.get_actions()
print(game_board.possible_actions)
# Out:
# Charlie
# [<bound method player.claim_territory of <risk_player.player object at 0x000001C8974CE880>>, <bound method player.assign_recruits of <risk_player.player object at 0x000001C8974CE880>>]

# %%
for key, value in game_board.game_board.territory_dict.items():
    #print(game_board.current_player.name)
    #print(game_board.current_player.free_troops)
    print(game_board.current_player)
    game_board.get_actions()
    game_board.perform_action(0, value)
# Out:
# Charlie
# 35
#
# Oana
# 35
#
# Charlie
# 34
# Alaska
#
# Oana
# 34
# Northwest Territory
#
# Charlie
# 33
# Alaska
# Greenland
#
# Oana
# 33
# Northwest Territory
# Alberta
#
# Charlie
# 32
# Alaska
# Greenland
# Ontario
#
# Oana
# 32
# Northwest Territory
# Alberta
# Quebec
#
# Charlie
# 31
# Alaska
# Greenland
# Ontario
# Western United States
#
# Oana
# 31
# Northwest Territory
# Alberta
# Quebec
# Eastern United States
#
# Charlie
# 30
# Alaska
# Greenland
# Ontario
# Western United States
# Central America
#
# Oana
# 30
# Northwest Territory
# Alberta
# Quebec
# Eastern United States
# Venezuela
#
# Charlie
# 29
# Alaska
# Greenland
# Ontario
# Western United States
# Central America
# Peru
#
# Oana
# 29
# Northwest Territory
# Alberta
# Quebec
# Eastern United States
# Venezuela
# Brazil
#
# Charlie
# 28
# Alaska
# Greenland
# Ontario
# Western United States
# Central America
# Peru
# Argentina
#
# Oana
# 28
# Northwest Territory
# Alberta
# Quebec
# Eastern United States
# Venezuela
# Brazil
# North Africa
#
# Charlie
# 27
# Alaska
# Greenland
# Ontario
# Western United States
# Central America
# Peru
# Argentina
# Egypt
#
# Oana
# 27
# Northwest Territory
# Alberta
# Quebec
# Eastern United States
# Venezuela
# Brazil
# North Africa
# East Africa
#
# Charlie
# 26
# Alaska
# Greenland
# Ontario
# Western United States
# Central America
# Peru
# Argentina
# Egypt
# Congo
#
# Oana
# 26
# Northwest Territory
# Alberta
# Quebec
# Eastern United States
# Venezuela
# Brazil
# North Africa
# East Africa
# South Africa
#
# Charlie
# 25
# Alaska
# Greenland
# Ontario
# Western United States
# Central America
# Peru
# Argentina
# Egypt
# Congo
# Madagascar
#
# Oana
# 25
# Northwest Territory
# Alberta
# Quebec
# Eastern United States
# Venezuela
# Brazil
# North Africa
# East Africa
# South Africa
# Iceland
#
# Charlie
# 24
# Alaska
# Greenland
# Ontario
# Western United States
# Central America
# Peru
# Argentina
# Egypt
# Congo
# Madagascar
# Scandinavia
#
# Oana
# 24
# Northwest Territory
# Alberta
# Quebec
# Eastern United States
# Venezuela
# Brazil
# North Africa
# East Africa
# South Africa
# Iceland
# Ukraine
#
# Charlie
# 23
# Alaska
# Greenland
# Ontario
# Western United States
# Central America
# Peru
# Argentina
# Egypt
# Congo
# Madagascar
# Scandinavia
# Great Britian
#
# Oana
# 23
# Northwest Territory
# Alberta
# Quebec
# Eastern United States
# Venezuela
# Brazil
# North Africa
# East Africa
# South Africa
# Iceland
# Ukraine
# Northern Europe
#
# Charlie
# 22
# Alaska
# Greenland
# Ontario
# Western United States
# Central America
# Peru
# Peru
# Argentina
# Egypt
# Congo
# Madagascar
# Scandinavia
# Great Britian
# Southern Europe
# Indonesia
# Western Australia
# Siam
# China
# Japan
# Yakutsk
# Siberia
#
# Oana
# 15
# Northwest Territory
# Alberta
# Quebec
# Eastern United States
# Venezuela
# Brazil
# North Africa
# East Africa
# South Africa
# Iceland
# Ukraine
# Northern Europe
# Western Europe
# New Guinea
# Eastern Australia
# India
# Mongolia
# Irkutsk
# Kamchatka
# Afghanistan

# %%
print(game_board.current_player.territory)
print(game_board.current_player.name)
print(game_board.current_player.free_troops)
# Out:
# [<risk_region.region object at 0x000001C897388370>, <risk_region.region object at 0x000001C897388E50>, <risk_region.region object at 0x000001C897388850>, <risk_region.region object at 0x000001C897474550>, <risk_region.region object at 0x000001C897474AF0>, <risk_region.region object at 0x000001C8974807C0>, <risk_region.region object at 0x000001C8974808E0>, <risk_region.region object at 0x000001C897480F70>, <risk_region.region object at 0x000001C897480E20>, <risk_region.region object at 0x000001C897480730>, <risk_region.region object at 0x000001C897480550>, <risk_region.region object at 0x000001C897480910>, <risk_region.region object at 0x000001C897480850>, <risk_region.region object at 0x000001C8974CE040>, <risk_region.region object at 0x000001C8974CE100>, <risk_region.region object at 0x000001C8974CE1C0>, <risk_region.region object at 0x000001C8974CE280>, <risk_region.region object at 0x000001C8974CE340>, <risk_region.region object at 0x000001C8974CE400>, <risk_region.region object at 0x000001C8974CE4C0>, <risk_region.region object at 0x000001C8974CE580>]
# Charlie
# 14

# %%
game_board.get_actions()
game_board.perform_action(1, game_board.game_board.territory_dict["Ural"], 14)

# %%
game_board.get_actions()
game_board.perform_action(1, game_board.game_board.territory_dict["Afghanistan"], 14)

# %%
for i  in game_board.players:
    print(i)
# Out:
# Charlie
# 0
# Alaska
# Greenland
# Ontario
# Western United States
# Central America
# Peru
# Argentina
# Egypt
# Congo
# Madagascar
# Scandinavia
# Great Britian
# Southern Europe
# Indonesia
# Western Australia
# Siam
# China
# Japan
# Yakutsk
# Siberia
# Ural
#
# Oana
# 0
# Northwest Territory
# Alberta
# Quebec
# Eastern United States
# Venezuela
# Brazil
# North Africa
# East Africa
# South Africa
# Iceland
# Ukraine
# Northern Europe
# Western Europe
# New Guinea
# Eastern Australia
# India
# Mongolia
# Irkutsk
# Kamchatka
# Afghanistan
# Middle East

# %%
game_board.perform_action(1, )
# Out:
# Oana
# 0
# Northwest Territory
# Alberta
# Quebec
# Eastern United States
# Venezuela
# Brazil
# North Africa
# East Africa
# South Africa
# Iceland
# Ukraine
# Northern Europe
# Western Europe
# New Guinea
# Eastern Australia
# India
# Mongolia
# Irkutsk
# Kamchatka
# Afghanistan
# Middle East

# %%
game_board.phase_controller()
game_board.turn_phase_control()
game_board.get_actions()
print(game_board.possible_actions)
game_board.perform_action(0, 2, game_board.game_board.territory_dict["Ural"], 2, game_board.game_board.territory_dict["Ukraine"])
print(game_board.game_board.territory_dict["Ural"].troops)
print(game_board.game_board.territory_dict["Ukraine"].troops)
# Out:
# [<bound method player.attack_territory of <risk_player.player object at 0x000001C8974CEA60>>, <bound method player.move_troops of <risk_player.player object at 0x000001C8974CEA60>>]
# You can't attack yourself
# 15
# 8
