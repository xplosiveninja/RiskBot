# %%
import risk_controller

# %%
game_board = risk_controller.board(["Charlie", "Oana"])

# %%
print(game_board.current_player.name)
game_board.get_actions()
print(game_board.possible_actions)
# Out:
# Charlie
# [<bound method player.claim_territory of <risk_player.player object at 0x000001B108600730>>, <bound method player.assign_recruits of <risk_player.player object at 0x000001B108600730>>]

# %%
for key, value in game_board.game_board.territory_dict.items():
    #print(game_board.current_player.name)
    #print(game_board.current_player.free_troops)
    print(game_board.current_player)
    game_board.get_actions()
    game_board.perform_action(0, value)
# Out:
# Charlie
# Free Troops : 35
#
# Player Cards :
#
# Possible Actions :
# claim_territory
# assign_recruits
#
# Controlled Territories :
#
# Oana
# Free Troops : 35
#
# Player Cards :
#
# Possible Actions :
# claim_territory
# assign_recruits
#
# Controlled Territories :
#
# Charlie
# Free Troops : 34
#
# Player Cards :
#
# Possible Actions :
# claim_territory
# assign_recruits
#
# Controlled Territories :
# Alaska : 1
#
# Oana
# Free Troops : 34
#
# Player Cards :
#
# Possible Actions :
# claim_territory
# assign_recruits
#
# Controlled Territories :
# Northwest Territory : 1
#
# Charlie
# Free Troops : 33
#
# Player Cards :
#
# Possible Actions :
# claim_territory
# assign_recruits
#
# Controlled Territories :
# Alaska : 1
# Greenland : 1
#
# Oana
# Free Troops : 33
#
# Player Cards :
#
# Possible Actions :
# claim_territory
# assign_recruits
#
# Controlled Territories :
# Northwest Territory : 1
# Alberta : 1
#
# Charlie
# Free Troops : 32
#
# Player Cards :
#
# Possible Actions :
# ...

# %%
print(game_board.current_player.territory)
print(game_board.current_player.name)
print(game_board.current_player.free_troops)
# Out:
# [<risk_region.region object at 0x000001B1085A4BB0>, <risk_region.region object at 0x000001B1085A4490>, <risk_region.region object at 0x000001B1085A4340>, <risk_region.region object at 0x000001B1085A4C10>, <risk_region.region object at 0x000001B1085A44F0>, <risk_region.region object at 0x000001B1085A4460>, <risk_region.region object at 0x000001B1085A4400>, <risk_region.region object at 0x000001B1085A4550>, <risk_region.region object at 0x000001B1085A4A30>, <risk_region.region object at 0x000001B1085A4B50>, <risk_region.region object at 0x000001B108600070>, <risk_region.region object at 0x000001B1086000D0>, <risk_region.region object at 0x000001B108600130>, <risk_region.region object at 0x000001B108600190>, <risk_region.region object at 0x000001B1086001F0>, <risk_region.region object at 0x000001B108600250>, <risk_region.region object at 0x000001B1086002B0>, <risk_region.region object at 0x000001B108600310>, <risk_region.region object at 0x000001B108600370>, <risk_region.region object a
# ...

# %%
game_board.get_actions()
game_board.perform_action(1, game_board.game_board.territory_dict["Ural"], 14)

# %%
game_board.get_actions()
game_board.perform_action(1, game_board.game_board.territory_dict["Afghanistan"], 14)

# %%
for i  in game_board.players:
    print(i)
# Out:
# Charlie
# Free Troops : 0
#
# Player Cards :
#
# Possible Actions :
# claim_territory
# assign_recruits
#
# Controlled Territories :
# Alaska : 1
# Greenland : 1
# Ontario : 1
# Western United States : 1
# Central America : 1
# Peru : 1
# Argentina : 1
# Egypt : 1
# Congo : 1
# Madagascar : 1
# Scandinavia : 1
# Great Britian : 1
# Southern Europe : 1
# Indonesia : 1
# Western Australia : 1
# Siam : 1
# China : 1
# Japan : 1
# Yakutsk : 1
# Siberia : 1
# Ural : 15
#
# Oana
# Free Troops : 0
#
# Player Cards :
#
# Possible Actions :
# claim_territory
# assign_recruits
#
# Controlled Territories :
# Northwest Territory : 1
# Alberta : 1
# Quebec : 1
# Eastern United States : 1
# Venezuela : 1
# Brazil : 1
# North Africa : 1
# East Africa : 1
# South Africa : 1
# Iceland : 1
# Ukraine : 1
# Northern Europe : 1
# Western Europe : 1
# New Guinea : 1
# Eastern Australia : 1
# India : 1
# Mongolia : 1
# Irkutsk : 1
# Kamchatka : 1
# Afghanistan : 15
# Middle East : 1

# %%
game_board.phase_controller()
game_board.turn_phase_control()
game_board.get_actions()
print(game_board.possible_actions)
game_board.perform_action(0, 2, game_board.game_board.territory_dict["Ural"], 2, game_board.game_board.territory_dict["Ukraine"])
print(game_board.game_board.territory_dict["Ural"].troops)
print(game_board.game_board.territory_dict["Ukraine"].troops)
# Out:
# [<bound method player.attack_territory of <risk_player.player object at 0x000001B108600730>>, <bound method player.move_troops of <risk_player.player object at 0x000001B108600730>>]
# 13
# 2

# %%
print(game_board.current_player)
# Out:
# Charlie
# Free Troops : 0
#
# Player Cards :
# Southern Europe : Armies.infantry
#
# Possible Actions :
# attack_territory
# move_troops
#
# Controlled Territories :
# Alaska : 1
# Greenland : 1
# Ontario : 1
# Western United States : 1
# Central America : 1
# Peru : 1
# Argentina : 1
# Egypt : 1
# Congo : 1
# Madagascar : 1
# Scandinavia : 1
# Great Britian : 1
# Southern Europe : 1
# Indonesia : 1
# Western Australia : 1
# Siam : 1
# China : 1
# Japan : 1
# Yakutsk : 1
# Siberia : 1
# Ural : 13
# Ukraine : 2
